# %%
#Lets import necessory libraries
import numpy as np
import pandas as pd

#For Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#import plotly
import warnings
warnings.filterwarnings('ignore')

# %%
#let load the dataset
data=pd.read_csv("bigmart.csv")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Top 5 row of the dataset
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#last 5 row of the dataset
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
#Lets check the shape of the dataset
data.shape
# Out:
# (8523, 12)

# %% [markdown]
# So,Here we have 8523 Rows and 12 columns

# %%
#Lets check for isnull
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# So , Here we have  null value in  Item_weight  and Outlet_Size column.So we will going to drop null value

# %%
data.drop(columns='Item_Weight',inplace=True)

# %%
data.drop(columns='Outlet_Size',inplace=True)

# %%
#Lets check the duplicated values
data.duplicated().sum()
# Out:
# 0

# %%
#Lets check the shape of the dataset again
data.shape
# Out:
# (8523, 10)

# %% [markdown]
# So, Now we have 8523 rows and 10 columns . Lets move foreword to check datatypes

# %%
#Lets check the datatype of the dataset
data.dtypes
# Out:
# Item_Identifier               object
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# So, here we have 6 object columns 3 float columns ,1 int columns

# %%
#Lets check the info of the datastet
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Location_Type       8523 non-null   object
#  8   Outlet_Type                8523 non-null   object
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 666.0+ KB

# %%
#lets check unique value in the dataset
data.nunique()
# Out:
# Item_Identifier              1559
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# Here we have unique value in each columns of the dataset

# %%
#Lets check statistical summary of the dataset
data.describe()
# Out:
#        Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count      8523.000000  8523.000000                8523.000000
# mean          0.066132   140.992782                1997.831867
# std           0.051598    62.275067                   8.371760
# min           0.000000    31.290000                1985.000000
# 25%           0.026989    93.826500                1987.000000
# 50%           0.053931   143.012800                1999.000000
# 75%           0.094585   185.643700                2004.000000
# max           0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # Observations

# %% [markdown]
# Item_MRP have outlier
#
# Item_Outlet_Sales have outlier

# %%
#Lets describe the dataset with object columns
data.describe(include='O')
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Location_Type        Outlet_Type
# count               8523                 8523               8523
# unique                10                    3                  4
# top               OUT027               Tier 3  Supermarket Type1
# freq                 935                 3350               5577

# %% [markdown]
# # Observations

# %% [markdown]
# We dont have any null values
#
# We have Unique Values in Columns

# %% [markdown]
# # EDA -> Exploratory Data Analysis

# %% [markdown]
# *Univariate Analysis

# %%
#lets plot Item_Type
sns.countplot(x='Item_Type',data=data,color='y')
plt.xticks(rotation=90)
plt.show()
data['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# So here we can see that items Fruits and vegetables is 1232 then snack food is 1200 ,less item were there of sea food is 64

# %%
#lets plot Outlet_Type
sns.countplot(x='Outlet_Type',data=data,color='y')
plt.xticks(rotation=90)
plt.show()
data['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
#lets plot Outlet_Type
outlet_type_counts = data['Outlet_Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(outlet_type_counts, labels=outlet_type_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Distribution of Outlet_Type')
plt.show()
print(outlet_type_counts)
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# here we can see that supermarket outlet has 5577 of big market

# %%
#lets plot Outlet_Establishment_Year
sns.countplot(x='Outlet_Establishment_Year',data=data,color='y')
plt.xticks(rotation=90)
plt.show()
data['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %% [markdown]
# here we know that big mart is oulet establishment year was 1985-2009.In 1985 big mart have 1463 outlet

# %%
#lets plot Item_Fat_Content
sns.countplot(x='Item_Fat_Content',data=data,color='y')
plt.xticks(rotation=90)
plt.show()
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# here we can know that big mart have low fat product in their outlet is 5089, regular 2889

# %%
#Lets plot Item_Outlet_Sales
sns.histplot(x='Item_Outlet_Sales',data=data,kde=True,color='black')
plt.show()
data['Item_Outlet_Sales'].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
# Create a violin plot for Item_Outlet_Sales
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Item_Outlet_Sales', color='black')
plt.xlabel('Item_Outlet_Sales')
plt.title('Distribution of Item_Outlet_Sales')
plt.show()
print(data['Item_Outlet_Sales'].describe())
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# here we can see that right skewed graph,and 958 approx 17 item outlet sales in big mart

# %%
#Lets plot Item_MRP
sns.histplot(x='Item_MRP',data=data,kde=True,color='black')
plt.show()
data['Item_MRP'].value_counts()
# Out:
# 172.0422    7
# 170.5422    6
# 196.5084    6
# 188.1872    6
# 142.0154    6
#            ..
# 97.3384     1
# 83.1934     1
# 96.6752     1
# 152.6682    1
# 75.4670     1
# Name: Item_MRP, Length: 5938, dtype: int64

# %% [markdown]
# from this graph 172 price 7 item was there in big mart,170 price 6 item  and so on...

# %%
#Lets plot Item_Visibility
sns.histplot(x='Item_Visibility',data=data,kde=True,color='green')
plt.show()
data['Item_Visibility'].value_counts()
# Out:
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64

# %% [markdown]
# This graph is right skewed

# %%
#Lets plot Outlet_Identifier
sns.histplot(x='Outlet_Identifier',data=data,kde=False,color='green')
plt.xticks(rotation=90)
plt.show()
data['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# From this graph 10 outlet Identifier was there in big mart, most of OUT027 935 product was there...

# %%
#lets plot Outlet_Location_Type
sns.countplot(x='Outlet_Location_Type',data=data,color='b')
plt.xticks(rotation=90)
plt.show()
data['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# Big mart have 3 Tier outlet location type was there in different loaction tier3 -3350 ,Tier2 2785,Tier1 -2388

# %% [markdown]
# # Bivariate Analysis

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Checking for numerical columns
numerical_col = []
for i in data.dtypes.index:
    if data.dtypes[i] != 'object':  # Check if the column is not of object type (i.e., numerical)
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming categorical_col contains the names of the numeric columns you want to plot
for i in numerical_col:
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=i, y="Item_Outlet_Sales", data=data)
    plt.title(f"Scatterplot of {i} vs. Item_Outlet_Sales")
    plt.xlabel(i)
    plt.ylabel("Item_Outlet_Sales")
    plt.show()

# %%
sns.regplot(data=data, x='Item_MRP', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# from this graph we came to know that 250 mrp price 12000 product were sold in big mart outlet

# %%
# Create a pair plot to visualize relationships
sns.set(style="ticks")
sns.pairplot(data=data, x_vars=['Item_Visibility'], y_vars=['Item_Outlet_Sales'], kind='reg', height=6, aspect=1.5)
plt.title('Pair Plot: Item_Visibility vs. Item_Outlet_Sales')
plt.xlabel('Item_Visibility')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.boxplot(data=data, x='Item_Fat_Content', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
sns.boxplot(data=data, x='Outlet_Location_Type', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.boxplot(data=data, x='Outlet_Establishment_Year', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data)
plt.show()

# %%
#Lets plot hist plot for all the data
data.hist(figsize=(15,15), bins=25)
plt.show()

# %%
#Lets Check for Outliers
#Select all numerical columns for ploting Distplot and Box plot
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = data.select_dtypes(include=numerics)
newdf
# Out:
#       Item_Visibility  Item_MRP  Outlet_Establishment_Year  Item_Outlet_Sales
# 0            0.016047  249.8092                       1999          3735.1380
# 1            0.019278   48.2692                       2009           443.4228
# 2            0.016760  141.6180                       1999          2097.2700
# 3            0.000000  182.0950                       1998           732.3800
# 4            0.000000   53.8614                       1987           994.7052
# ...               ...       ...                        ...                ...
# 8518         0.056783  214.5218                       1987          2778.3834
# 8519         0.046982  108.1570                       2002           549.2850
# 8520         0.035186   85.1224                       2004          1193.1136
# 8521         0.145221  103.1332                       2009          1845.5976
# 8522         0.044878   75.4670                       1997           765.6700
#
# [8523 rows x 4 columns]

# %%
#Lets plot displot
for i in newdf:
    plt.figure()
    sns.distplot(newdf[i])
    
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# So Here ,
#
# *Item visibility have right skewed
#
# *Item MRP have normal Distribution
#
# *Outlet establishment have normal Distribution
#
# *item outlet sales have  right skewed

# %%
#Lets plot Boxplot
for i in newdf:
    plt.figure()
    sns.boxplot(y=newdf[i])
    
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# *item visibiliy have outlier
#
# *Item Outlet sales have outlier but its is a target value ,will not remove it.we can consider it

# %% [markdown]
# # Data Preprocessing

# %%
#Lets Check for Outliers
#Select all numerical columns for ploting Distplot and Box plot
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = data.select_dtypes(include=numerics)
newdf
# Out:
#       Item_Visibility  Item_MRP  Outlet_Establishment_Year  Item_Outlet_Sales
# 0            0.016047  249.8092                       1999          3735.1380
# 1            0.019278   48.2692                       2009           443.4228
# 2            0.016760  141.6180                       1999          2097.2700
# 3            0.000000  182.0950                       1998           732.3800
# 4            0.000000   53.8614                       1987           994.7052
# ...               ...       ...                        ...                ...
# 8518         0.056783  214.5218                       1987          2778.3834
# 8519         0.046982  108.1570                       2002           549.2850
# 8520         0.035186   85.1224                       2004          1193.1136
# 8521         0.145221  103.1332                       2009          1845.5976
# 8522         0.044878   75.4670                       1997           765.6700
#
# [8523 rows x 4 columns]

# %% [markdown]
# # i) Outliers Handling

# %%
import numpy as np
from scipy.stats import zscore

# %%
features = data[['Item_Visibility']]

# %%
# Using zscore to remove outliers
z=np.abs(zscore(features))
z
# Out:
#       Item_Visibility
# 0            0.970732
# 1            0.908111
# 2            0.956917
# 3            1.281758
# 4            1.281758
# ...               ...
# 8518         0.181193
# 8519         0.371154
# 8520         0.599784
# 8521         1.532880
# 8522         0.411936
#
# [8523 rows x 1 columns]

# %%
# Creating new dataframe
new_df = data[(z<3).all(axis=1)] 
new_df
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
# Shape of original dataset
data.shape
# Out:
# (8523, 10)

# %%
#After Removing Outliers
new_df.shape
# Out:
# (8338, 10)

# %%
# Checking the the data loss
data_loss = (8523-8338)/8523*100
data_loss
# Out:
# 2.170597207556025

# %% [markdown]
# Here we loss 2.170 % Data

# %% [markdown]
# # ii) IQR (Inter Quantile Range) method

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df1=data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
#After removing outlier
df1.shape
# Out:
# (8379, 10)

# %%
# Shape of original dataset
data.shape
# Out:
# (8523, 10)

# %%
# Checking the the data loss
data_loss = (8523-8379)/8523*100
data_loss
# Out:
# 1.689545934530095

# %% [markdown]
# So, in IQR Method we can see that we lost out 1.68 % data . lets move foreward with IQR Method if we dont get better result with IQR Method then we choose Z Score Method

# %% [markdown]
# # Encoding the categorical columns using Label Encoding

# %%
# checking for categorical columns
categorical_col=[]
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Location_Type', 'Outlet_Type']

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
new_df[categorical_col]= new_df[categorical_col].apply(LE.fit_transform)

# %%
new_df[categorical_col]
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0                 156                 1          4                  9
# 1                   8                 2         14                  3
# 2                 662                 1         10                  9
# 3                1121                 2          6                  0
# 4                1297                 1          9                  1
# ...               ...               ...        ...                ...
# 8518              370                 1         13                  1
# 8519              897                 2          0                  7
# 8520             1357                 1          8                  6
# 8521              681                 2         13                  3
# 8522               50                 1         14                  8
#
#       Outlet_Location_Type  Outlet_Type
# 0                        0            1
# 1                        2            2
# ...

# %% [markdown]
# # observation

# %% [markdown]
# Outlet type              lE
#    *Super market type 1= 1
#
#    * Super market type 2= 2
#
#     * grocey store= 0
#
#     * Super market type 3= 3
#
# Outet location type
#   *Tier 3=2
#
#   *Tier 1= 0
#
#   *Tier 2=1

# %%
new_df
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 156                 1         0.016047          4  249.8092
# 1                   8                 2         0.019278         14   48.2692
# 2                 662                 1         0.016760         10  141.6180
# 3                1121                 2         0.000000          6  182.0950
# 4                1297                 1         0.000000          9   53.8614
# ...               ...               ...              ...        ...       ...
# 8518              370                 1         0.056783         13  214.5218
# 8519              897                 2         0.046982          0  108.1570
# 8520             1357                 1         0.035186          8   85.1224
# 8521              681                 2         0.145221         13  103.1332
# 8522               50                 1         0.044878         14   75.4670
#
# ...

# %% [markdown]
# # Correlation between the target variable and features using HEAT map

# %%
# Checking the correlation
cor = new_df.corr()
cor
# Out:
#                            Item_Identifier  Item_Fat_Content  Item_Visibility  \
# Item_Identifier                   1.000000         -0.098893        -0.025231
# Item_Fat_Content                 -0.098893          1.000000         0.037356
# Item_Visibility                  -0.025231          0.037356         1.000000
# Item_Type                        -0.015179         -0.114818        -0.037675
# Item_MRP                          0.014696         -0.001638         0.000153
# Outlet_Identifier                -0.009507         -0.001957        -0.070073
# Outlet_Establishment_Year        -0.013690          0.000279        -0.044366
# Outlet_Location_Type              0.002106         -0.004345        -0.015150
# Outlet_Type                      -0.003624         -0.004163        -0.120117
# Item_Outlet_Sales                 0.004547          0.009810        -0.091955
#
#                            Item_Type  Item_MRP  Outlet_Identifier  \
# ...

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(25,22))
sns.heatmap(new_df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %% [markdown]
# # Visualizing the correlation between label(y) and features using bar plot

# %%
plt.figure(figsize=(22,7))
new_df.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=10)
plt.ylabel('target',fontsize=10)
plt.title('correlation between label and feature using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# Here we can see that.
#
# Positive correlation-> item mRP,outlet type,outlet identifier,outlet location type, item type,item fat content,item identifier'
#
# Negative Correlation -> outlet establishment year,item visibility

# %% [markdown]
# # Model Building

# %%
x = new_df.drop("Item_Outlet_Sales", axis=1)
y = new_df["Item_Outlet_Sales"]

# %%
x.shape
# Out:
# (8338, 9)

# %%
y.shape
# Out:
# (8338,)

# %%
# Checking skewness 
x.skew()
# Out:
# Item_Identifier             -0.007837
# Item_Fat_Content             1.008251
# Item_Visibility              0.794272
# Item_Type                    0.098295
# Item_MRP                     0.138990
# Outlet_Identifier           -0.065135
# Outlet_Establishment_Year   -0.423379
# Outlet_Location_Type        -0.202674
# Outlet_Type                  0.956727
# dtype: float64

# %% [markdown]
# Here we set a threshold for +-5.

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    Item_Identifier  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0        -1.386901         -0.571925        -1.011507  -0.766589  1.771831
# 1        -1.715672          0.978372        -0.943320   1.610171 -1.482939
# 2        -0.262861         -0.571925        -0.996464   0.659467  0.024597
# 3         0.756773          0.978372        -1.350181  -0.291237  0.678281
# 4         1.147744         -0.571925        -1.350181   0.421791 -1.392628
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Location_Type  \
# 0           1.496012                   0.120549             -1.370345
# 1          -0.615022                   1.322724              1.099060
# 2           1.496012                   0.120549             -1.370345
# 3          -1.670540                   0.000332              1.099060
# 4          -1.318700                  -1.322060              1.099060
#
#    Outlet_Type
# 0    -0.259839
# 1     1.022134
# 2    -0.259839
# 3    -1.541811
# ...

# %% [markdown]
# # Checking VIF values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#    VIF values                   Features
# 0    1.011808            Item_Identifier
# 1    1.024923           Item_Fat_Content
# 2    1.024573            Item_Visibility
# 3    1.016366                  Item_Type
# 4    1.002204                   Item_MRP
# 5    4.140393          Outlet_Identifier
# 6    1.031243  Outlet_Establishment_Year
# 7    5.209071       Outlet_Location_Type
# 8    2.540184                Outlet_Type

# %% [markdown]
# # Checking Feature Selection Technique

# %%
# Lets use any other feature selection technique
from sklearn.feature_selection import SelectKBest,f_classif

# %%
select_feature=SelectKBest(score_func=f_classif,k=9)
fit=select_feature.fit(x,y)
score=pd.DataFrame(fit.scores_)
column=pd.DataFrame(x.columns)

best_feature=pd.concat([column,score],axis=1)
best_feature.columns=['Feature','Score']
print(best_feature.nlargest(10,'Score'))
# Out:
#                      Feature     Score
# 4                   Item_MRP  3.478654
# 8                Outlet_Type  2.028020
# 5          Outlet_Identifier  1.211107
# 3                  Item_Type  1.199345
# 6  Outlet_Establishment_Year  1.193465
# 2            Item_Visibility  1.149438
# 0            Item_Identifier  1.145568
# 1           Item_Fat_Content  1.095598
# 7       Outlet_Location_Type  1.036423

# %% [markdown]
# # Model Building

# %% [markdown]
# # Linear Regression

# %%
#Lets create with random forest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 50):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5130664552215622 on Random State 43

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=43)

# %%
regressors = {
    
    'Linear Regression' : LinearRegression(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
results
# Out:
#                        MAE          MSE        RMSE  R2-score
# Linear Regression  861.139  1239780.189  1113.45417     0.513

# %% [markdown]
# # Cross Validation of the Model

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
# from sklearn.model_selection import cross_val_score
for j in range(2,10):
    isscore = cross_val_score(lr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 48.64359433164492
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 3
# Cross validation score is:- 48.655139054372626
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 4
# Cross validation score is:- 48.6414404824695
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 5
# Cross validation score is:- 48.67903919321238
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 6
# Cross validation score is:- 48.70184157520439
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 7
# Cross validation score is:- 48.729690219040705
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 8
# Cross validation score is:- 48.706574028569364
# accuracy_score is:- 51.306645522156224
#
#
# At cv:- 9
# Cross validation score is:- 48.70282992337953
# accuracy_score is:- 51.306645522156224

# %% [markdown]
# # KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(100, 200):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    pred = knn.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5440876106334734 on Random State 133

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=133)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=164)
regressors = {
    
    'KNN Regressor': KNeighborsRegressor()
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
print(results)
# Out:
#                    MAE          MSE         RMSE  R2-score
# KNN Regressor  834.796  1338024.207  1156.729963     0.464

# %% [markdown]
# # Cross Validation of the Model

# %%
KNN = KNeighborsRegressor()
KNN.fit(X_train,y_train)
y_pred = KNN.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(2,10):
    isscore = cross_val_score(KNN,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 49.01201771577794
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 3
# Cross validation score is:- 49.40262108695169
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 4
# Cross validation score is:- 49.477797774558766
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 5
# Cross validation score is:- 49.343262539726105
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 6
# Cross validation score is:- 49.81275825914635
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 7
# Cross validation score is:- 49.3810807645069
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 8
# Cross validation score is:- 49.458284952983696
# accuracy_score is:- 46.35009507997842
#
#
# At cv:- 9
# Cross validation score is:- 49.50431476698059
# accuracy_score is:- 46.35009507997842

# %% [markdown]
# # XGBRegressor

# %%
from xgboost import XGBRegressor
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(0, 100):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    xgb = XGBRegressor()
    xgb.fit(X_train, y_train)
    pred = xgb.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5456475427206986 on Random State 82

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=82)

# %%
regressors = {
    
    'XG Boost Regressor' : XGBRegressor()
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
    print(results)
# Out:
#                         MAE          MSE         RMSE  R2-score
# XG Boost Regressor  804.725  1242511.842  1114.680152     0.546

# %% [markdown]
# # Cross Validation of the Model

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)

y_pred = xgb.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(2,10):
    isscore = cross_val_score(xgb,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 2
# Cross validation score is:- 48.26244393659182
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 3
# Cross validation score is:- 49.43435448185376
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 4
# Cross validation score is:- 49.75669177611398
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 5
# Cross validation score is:- 50.0339123529418
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 6
# Cross validation score is:- 50.878052178030174
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 7
# Cross validation score is:- 51.196044712992375
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 8
# Cross validation score is:- 50.42827261348036
# accuracy_score is:- 54.56475427206986
#
#
# At cv:- 9
# Cross validation score is:- 49.93825104789191
# accuracy_score is:- 54.56475427206986

# %% [markdown]
# we got best accuracy with XGB Regressor so we use that model in our pipeline.Now we are doing Hyper parameter tunning

# %% [markdown]
# # Hyper parameter tuning

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [200],      # Number of estimators (trees)
    'learning_rate': [0.01],   # Learning rate
    'max_depth': [10],         # Maximum depth of the trees
    'min_child_weight': [7],   # Minimum sum of instance weight (hessian) needed in a child
    'subsample': [0.10],       # Fraction of samples used for fitting the trees
}

# Create the XGBRegressor
xgb_regressor = xgb.XGBRegressor()

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_regressor, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model to the data to search for the best hyperparameters
grid_search.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# Create a new XGBRegressor with the best hyperparameters
best_xgb_regressor = xgb.XGBRegressor(**best_params)

# Train the model with the best hyperparameters
best_xgb_regressor.fit(X_train, y_train)

# Make predictions with the best model
pred = best_xgb_regressor.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)

# Print the best hyperparameters and evaluation metrics
print("Best Hyperparameters:", best_params)
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2-score:", r2)
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 7, 'n_estimators': 200, 'subsample': 0.1}
# MAE: 767.8202286988477
# MSE: 1034304.3137521605
# RMSE: 1017.0075288571666
# R2-score: 0.5879178071620816

# %% [markdown]
# # Best fit line

# %%
plt.scatter(y_test,pred)
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.title(' Best fit line')
plt.tight_layout()

# %% [markdown]
# # Conclusion

# %%
import pickle
filename=('Linear Regression Project')
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Linear Regression Project','rb'))
result=loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 49.9673605581393

# %%
conclusion=pd.DataFrame([loaded_model.predict(X_train)[:],pred[:]],index=['predicted','original'])
conclusion
# Out:
#                   0            1            2            3            4     \
# predicted  2372.586324  2396.217113  3427.869684  2058.066325   618.744658
# original    476.972517  1495.841192  3134.256877   547.959211  1282.914117
#
#                   5            6            7            8           9     \
# predicted  2416.483547  4300.967190  3451.145464  2708.619513  288.136855
# original   3601.550954  2722.593647  1745.285915  3659.004451  666.112681
#
#            ...         6660         6661        6662         6663  \
# predicted  ...  2113.786734  2325.416639  820.238459  1683.985131
# original   ...          NaN          NaN         NaN          NaN
#
#                   6664         6665         6666         6667        6668  \
# predicted  2616.948647  2018.746215  3984.030963  2549.917255  1156.66671
# original           NaN          NaN          NaN          NaN         NaN
#
#                  6669
# predicted  441.926723
# original          NaN
#
# ...
