# %%
#Lets import necessory libraries
import numpy as np
import pandas as pd

#For Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#import plotly
import warnings
warnings.filterwarnings('ignore')

# %%
#let load the dataset
data=pd.read_csv("Wholesale customers data.csv")
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
#Top 5 row of the dataset
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
#last 5 row of the dataset
data.tail()
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52

# %% [markdown]
# So, Here we have 440 Rows and 5 Columns

# %%
#Lets check for isnull
data.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %% [markdown]
# So , Here we don`t have any null value in any column. It is good we can proceed to next

# %%
data.drop(columns='Region',inplace=True)

# %% [markdown]
# we have drop region columns from our dataset.

# %%
#Lets check the duplicated values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# we don`t have any duplicate value in our dataset

# %%
#Lets check the shape of the dataset again
data.shape
# Out:
# (440, 7)

# %% [markdown]
# So, Here we have 440 Rows and 7 Columns

# %%
#Lets check the datatype of the dataset
data.dtypes
# Out:
# Channel             int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %% [markdown]
# so we have all data type is int

# %%
#Lets check the info of the datastet
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Fresh             440 non-null    int64
#  2   Milk              440 non-null    int64
#  3   Grocery           440 non-null    int64
#  4   Frozen            440 non-null    int64
#  5   Detergents_Paper  440 non-null    int64
#  6   Delicassen        440 non-null    int64
# dtypes: int64(7)
# memory usage: 24.2 KB

# %%
#lets check unique value in the dataset
data.nunique()
# Out:
# Channel               2
# Fresh               433
# Milk                421
# Grocery             430
# Frozen              426
# Detergents_Paper    417
# Delicassen          403
# dtype: int64

# %% [markdown]
# Here we have unique value in each columns of the dataset

# %%
#Lets check statistical summary of the dataset
data.describe()
# Out:
#           Channel          Fresh          Milk       Grocery        Frozen  \
# count  440.000000     440.000000    440.000000    440.000000    440.000000
# mean     1.322727   12000.297727   5796.265909   7951.277273   3071.931818
# std      0.468052   12647.328865   7380.377175   9503.162829   4854.673333
# min      1.000000       3.000000     55.000000      3.000000     25.000000
# 25%      1.000000    3127.750000   1533.000000   2153.000000    742.250000
# 50%      1.000000    8504.000000   3627.000000   4755.500000   1526.000000
# 75%      2.000000   16933.750000   7190.250000  10655.750000   3554.250000
# max      2.000000  112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper    Delicassen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# ...

# %% [markdown]
# # observations

# %% [markdown]
# * we don`t have null value
#
# * fresh have outlier
#
# * Milk have outlier
#
# * Grocery have outlier
# *Frozen have outlier
# *Detergents_paper have outlier
# *Delicassen have outlier

# %% [markdown]
# # EDA -> Exploratory Data Analysis

# %%
#lets plot channel
sns.countplot(x='Channel',data=data,color='g')
plt.xticks(rotation=90)
plt.show()
data['Channel'].value_counts()
# Out:
# 1    298
# 2    142
# Name: Channel, dtype: int64

# %% [markdown]
# Here we can see that channel have  1 channel is 298 and 2 channel is 142

# %%
# Plot a bar plot for Fresh
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
sns.countplot(x='Fresh', data=data, color='g')
plt.xticks(rotation=90)  # Rotate the x-axis labels for better visibility
plt.xlabel('Fresh')  # Add x-axis label if needed
plt.ylabel('Count')  # Add y-axis label if needed
plt.title('Distribution of Channel')  # Add a title if needed
plt.show()
print(data['Fresh'].value_counts())
# Out:
# 9670     2
# 3        2
# 18044    2
# 8040     2
# 514      2
#         ..
# 18827    1
# 10405    1
# 37036    1
# 30379    1
# 2787     1
# Name: Fresh, Length: 433, dtype: int64

# %% [markdown]
# here we can see that approx 2 have fresh in wholesale customer data

# %%
#Lets plot Detergents paper
sns.histplot(x='Detergents_Paper',data=data,kde=True,color='black')
plt.show()
data['Detergents_Paper'].value_counts()
# Out:
# 118    2
# 955    2
# 256    2
# 69     2
# 918    2
#       ..
# 516    1
# 399    1
# 51     1
# 960    1
# 477    1
# Name: Detergents_Paper, Length: 417, dtype: int64

# %% [markdown]
# here we can see that it is right skewed

# %%
#Lets plot Frozen
sns.histplot(x='Frozen',data=data,kde=True,color='black')
plt.show()
data['Frozen'].value_counts()
# Out:
# 2540    2
# 425     2
# 1285    2
# 4324    2
# 1619    2
#        ..
# 2995    1
# 321     1
# 2279    1
# 825     1
# 65      1
# Name: Frozen, Length: 426, dtype: int64

# %% [markdown]
# here we can see that it is right skewed

# %%
#Lets plot Delicassen
sns.boxplot(x='Delicassen',data=data,color='blue')
plt.show()
data['Delicassen'].value_counts()
# Out:
# 3       4
# 834     4
# 548     3
# 610     3
# 395     3
#        ..
# 318     1
# 1450    1
# 2616    1
# 929     1
# 52      1
# Name: Delicassen, Length: 403, dtype: int64

# %% [markdown]
# here we can see that approx 4 have delicassen in wholesale customer data.It also have outlier

# %%
# Create a violin plot for Milk
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Milk', color='black')
plt.xlabel('Milk')
plt.title('Distribution of Item_Outlet_Sales')
plt.show()

# %% [markdown]
# here we have see than approx 20,000 milk whosale customer have .Its also have outlier

# %%
#Lets plot Item_Outlet_Sales
sns.histplot(x='Grocery',data=data,kde=True,color='black')
plt.show()
data['Grocery'].value_counts()
# Out:
# 1664    2
# 2062    2
# 683     2
# 3600    2
# 6536    2
#        ..
# 7305    1
# 3343    1
# 5034    1
# 8282    1
# 2510    1
# Name: Grocery, Length: 430, dtype: int64

# %% [markdown]
# here we have see than approx 240,000 Grocery whosale customer have .Its is right skewed

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(data)
plt.show()

# %%
#Lets plot hist plot for all the data
data.hist(figsize=(15,15), bins=25)
plt.show()

# %%
#Lets Check for Outliers
#Select all numerical columns for ploting Distplot and Box plot
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = data.select_dtypes(include=numerics)
newdf
# Out:
#      Channel  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0          2  12669   9656     7561     214              2674        1338
# 1          2   7057   9810     9568    1762              3293        1776
# 2          2   6353   8808     7684    2405              3516        7844
# 3          1  13265   1196     4221    6404               507        1788
# 4          2  22615   5410     7198    3915              1777        5185
# ..       ...    ...    ...      ...     ...               ...         ...
# 435        1  29703  12051    16027   13135               182        2204
# 436        1  39228   1431      764    4510                93        2346
# 437        2  14531  15488    30243     437             14841        1867
# 438        1  10290   1981     2232    1038               168        2125
# 439        1   2787   1698     2510      65               477          52
#
# [440 rows x 7 columns]

# %%
#Lets plot displot
for i in newdf:
    plt.figure()
    sns.distplot(newdf[i])
    
    plt.xticks(rotation=90)
    plt.show()

# %%
#Lets plot Boxplot
for i in newdf:
    plt.figure()
    sns.boxplot(y=newdf[i])
    
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # observation

# %% [markdown]
# fresh have outlier
#
# Milk have outlier
#
# Grocery have outlier
#
# Frozen have outlier
#
# Detergents_paper have outlier
#
# Delicassen have outlier

# %%
#Lets Check for Outliers
#Select all numerical columns for ploting Distplot and Box plot
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = data.select_dtypes(include=numerics)
newdf
# Out:
#      Channel  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0          2  12669   9656     7561     214              2674        1338
# 1          2   7057   9810     9568    1762              3293        1776
# 2          2   6353   8808     7684    2405              3516        7844
# 3          1  13265   1196     4221    6404               507        1788
# 4          2  22615   5410     7198    3915              1777        5185
# ..       ...    ...    ...      ...     ...               ...         ...
# 435        1  29703  12051    16027   13135               182        2204
# 436        1  39228   1431      764    4510                93        2346
# 437        2  14531  15488    30243     437             14841        1867
# 438        1  10290   1981     2232    1038               168        2125
# 439        1   2787   1698     2510      65               477          52
#
# [440 rows x 7 columns]

# %% [markdown]
# # 1)Outliers Handling

# %%
import numpy as np
from scipy.stats import zscore

# %%
features = data[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']]

# %%
# Using zscore to remove outliers
z=np.abs(zscore(features))
z
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# 0    0.052933  0.523568  0.041115  0.589367          0.043569    0.066339
# 1    0.391302  0.544458  0.170318  0.270136          0.086407    0.089151
# 2    0.447029  0.408538  0.028157  0.137536          0.133232    2.243293
# 3    0.100111  0.624020  0.392977  0.687144          0.498588    0.093411
# 4    0.840239  0.052396  0.079356  0.173859          0.231918    1.299347
# ..        ...       ...       ...       ...               ...         ...
# 435  1.401312  0.848446  0.850760  2.075222          0.566831    0.241091
# 436  2.155293  0.592142  0.757165  0.296561          0.585519    0.291501
# 437  0.200326  1.314671  2.348386  0.543380          2.511218    0.121456
# 438  0.135384  0.517536  0.602514  0.419441          0.569770    0.213046
# 439  0.729307  0.555924  0.573227  0.620094          0.504888    0.522869
#
# [440 rows x 6 columns]

# %%
# Creating new dataframe
new_df = data[(z<3).all(axis=1)] 
new_df
# Out:
#      Channel  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0          2  12669   9656     7561     214              2674        1338
# 1          2   7057   9810     9568    1762              3293        1776
# 2          2   6353   8808     7684    2405              3516        7844
# 3          1  13265   1196     4221    6404               507        1788
# 4          2  22615   5410     7198    3915              1777        5185
# ..       ...    ...    ...      ...     ...               ...         ...
# 435        1  29703  12051    16027   13135               182        2204
# 436        1  39228   1431      764    4510                93        2346
# 437        2  14531  15488    30243     437             14841        1867
# 438        1  10290   1981     2232    1038               168        2125
# 439        1   2787   1698     2510      65               477          52
#
# [414 rows x 7 columns]

# %%
# Shape of original dataset
data.shape
# Out:
# (440, 7)

# %%
#After Removing Outliers
new_df.shape
# Out:
# (414, 7)

# %%
# Checking the the data loss
data_loss = (440-414)/440*100
data_loss
# Out:
# 5.909090909090909

# %% [markdown]
# Here we loss 2.170 % Data

# %% [markdown]
# # ii) IQR (Inter Quantile Range) method

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df1=data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
#After removing outlier
df1.shape
# Out:
# (332, 7)

# %%
# Shape of original dataset
data.shape
# Out:
# (440, 7)

# %%
# Checking the the data loss
data_loss = (440-332)/440*100
data_loss
# Out:
# 24.545454545454547

# %% [markdown]
# So, in IQR Method we can see that we lost out 24.54 % data . lets move foreward with Z score if we dont get better result with Z Score Method then we choose IQR Method.

# %% [markdown]
# # Correlation between the target variable and features using HEAT map

# %%
# Checking the correlation
cor = new_df.corr()
cor
# Out:
#                    Channel     Fresh      Milk   Grocery    Frozen  \
# Channel           1.000000 -0.168044  0.558492  0.716810 -0.237060
# Fresh            -0.168044  1.000000 -0.126575 -0.179004  0.241618
# Milk              0.558492 -0.126575  1.000000  0.722141 -0.068356
# Grocery           0.716810 -0.179004  0.722141  1.000000 -0.190469
# Frozen           -0.237060  0.241618 -0.068356 -0.190469  1.000000
# Detergents_Paper  0.742669 -0.254487  0.622947  0.867060 -0.240503
# Delicassen        0.177331  0.142430  0.356101  0.223917  0.108489
#
#                   Detergents_Paper  Delicassen
# Channel                   0.742669    0.177331
# Fresh                    -0.254487    0.142430
# Milk                      0.622947    0.356101
# Grocery                   0.867060    0.223917
# Frozen                   -0.240503    0.108489
# Detergents_Paper          1.000000    0.115172
# Delicassen                0.115172    1.000000

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(25,22))
sns.heatmap(new_df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0);

# %%
#dataset
X =data[['Channel', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper',
       'Delicassen']]
X.head()
# Out:
#    Channel  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2  12669  9656     7561     214              2674        1338
# 1        2   7057  9810     9568    1762              3293        1776
# 2        2   6353  8808     7684    2405              3516        7844
# 3        1  13265  1196     4221    6404               507        1788
# 4        2  22615  5410     7198    3915              1777        5185

# %%
#Elbow method
from sklearn.cluster import KMeans

wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
data.shape
# Out:
# (440, 7)

# %%
data.head()
# Out:
#    Channel  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2  12669  9656     7561     214              2674        1338
# 1        2   7057  9810     9568    1762              3293        1776
# 2        2   6353  8808     7684    2405              3516        7844
# 3        1  13265  1196     4221    6404               507        1788
# 4        2  22615  5410     7198    3915              1777        5185

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 4, random_state = 42)
y_kmeans = kmeans.fit_predict(X)
print(y_kmeans)
# Out:
# [2 0 2 2 1 2 2 2 2 0 0 2 1 0 1 2 0 2 2 2 2 2 1 3 1 2 2 2 0 1 2 2 2 1 2 0 1
#  0 0 1 1 2 0 0 2 0 0 3 2 0 2 2 1 0 1 2 0 0 2 2 2 3 2 0 2 3 2 2 2 2 2 0 2 2
#  2 2 2 0 2 2 2 0 0 2 2 3 3 1 2 1 2 2 3 2 0 2 2 2 2 2 0 0 2 1 2 2 0 0 2 0 2
#  0 2 2 2 2 2 2 2 2 2 2 2 2 1 1 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 1 1 2 2 0 2 2
#  2 1 2 2 2 2 2 0 0 2 0 0 0 2 2 0 2 0 0 2 2 2 0 0 2 0 2 0 1 2 2 2 2 1 0 3 2
#  2 2 0 0 0 2 2 2 0 2 2 1 0 2 2 0 0 1 2 2 0 2 2 2 0 2 3 2 2 0 0 0 2 0 2 2 0
#  2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 1 1 1 2 2 0 0 2 2 2 2 2 3 2 1 2 1 2 2 1
#  1 2 2 2 2 0 0 0 2 0 2 2 2 2 1 2 2 1 2 2 2 2 2 1 1 1 1 2 2 2 1 2 2 2 0 2 2
#  2 2 2 2 2 0 0 0 0 0 0 2 2 0 2 1 0 2 2 0 2 2 2 0 2 2 2 2 1 1 2 2 2 2 2 0 2
#  3 2 1 2 2 2 2 0 0 2 0 2 2 0 1 2 0 2 0 2 0 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2
#  1 2 2 2 2 2 0 1 2 2 1 2 1 2 0 2 2 2 2 2 2 2 2 1 2 2 0 2 2 2 2 1 1 1 2 2 1
#  0 2 2 2 2 0 2 2 2 0 0 0 2 0 2 1 2 2 2 0 1 2 2 0 2 2 2 2 1 1 0 2 2]

# %% [markdown]
# # Model Evaluation

# %%
# Just like in supervised learning we have a metric in unsupervised learning as well
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X,y_kmeans)
# Out:
# 0.3866313699117264

# %% [markdown]
# # Sample prediction

# %%
# It predicts the cluster number to which the datapoint belongs to
test=kmeans.predict(np.asarray([[2,22615,5410,7198,3915,1777,5185]]))
test[0]
# Out:
# 1

# %%
# Keep same cluster customers in seperate dataset
cluster_4_wholesale= X[y_kmeans==4]
print (cluster_4_wholesale)
# Out:
# Empty DataFrame
# Columns: [Channel, Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen]
# Index: []

# %%
import matplotlib.pyplot as plt

# Visualising the clusters
plt.figure(figsize=(8, 5))

# Assuming X is a DataFrame with columns 'Channel', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen'
# y_kmeans is a variable containing cluster assignments for each data point

# Scatter plot for Cluster 1 (assuming y_kmeans == 0 for Cluster 1)
plt.scatter(X[y_kmeans == 0]['Channel'], X[y_kmeans == 0]['Fresh'], s=100, c='red', label='Cluster 1')

# Scatter plot for Cluster 2 (assuming y_kmeans == 1 for Cluster 2)
plt.scatter(X[y_kmeans == 1]['Channel'], X[y_kmeans == 1]['Fresh'], s=100, c='blue', label='Cluster 2')

# Scatter plot for Cluster 3 (assuming y_kmeans == 2 for Cluster 3)
plt.scatter(X[y_kmeans == 2]['Channel'], X[y_kmeans == 2]['Fresh'], s=100, c='green', label='Cluster 3')

# Scatter plot for Cluster 4 (assuming y_kmeans == 3 for Cluster 4)
plt.scatter(X[y_kmeans == 3]['Channel'], X[y_kmeans == 3]['Fresh'], s=100, c='cyan', label='Cluster 4')



# Plotting cluster centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='black', label='Centroids')

plt.title('Clusters of customers')
plt.xlabel('Channel')
plt.ylabel('Fresh')
plt.legend()
plt.show()

# %%
#Student of DataTrained-Ruzaina Khan
#Date-5-10-2023
